# %%
from pathlib import Path
import os

import pandas as pd

THIS_PATH = Path(os.getcwd())
ROOT_PATH = THIS_PATH.parent.absolute()
DATA_PATH = ROOT_PATH / 'data'
RAW_PATH = DATA_PATH / 'raw'

accepted_data_filename = 'accepted_2007_to_2018Q4.csv'
rejected_data_filename = 'rejected_2007_to_2018Q4.csv'

accepted_data_path = RAW_PATH / accepted_data_filename / accepted_data_filename
rejected_data_path = RAW_PATH / rejected_data_filename / rejected_data_filename

# check if files exist
if not accepted_data_path.exists():
    raise FileNotFoundError

if not rejected_data_path.exists():
    raise FileNotFoundError
