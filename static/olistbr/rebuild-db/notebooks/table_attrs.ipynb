# %%
import os
from pathlib import Path

import pandas as pd
from pandas import DataFrame
from icecream import ic

from src.utils.infer import infer_dtypes
from src.utils.paths import RAW_PATH

# %%
raw_files = os.listdir(RAW_PATH)

filepaths: list[Path] = []
dfs: dict[str, DataFrame] = dict()

for raw_file in raw_files:
    filepath = RAW_PATH / raw_file
    filepaths.append(filepath)

    if not filepath.exists():
        raise FileNotFoundError

    dfs[filepath.name] = pd.read_csv(filepath, dtype=object)

# %%
pd.set_option("display.max_columns", None)

# filename = "olist_" + "geolocation" + "_dataset.csv"
# df = dfs[filename]

# df_attributes = infer_dtypes(df)
# df_attributes

# %%
filename = "olist_" + "customers" + "_dataset.csv"
df = dfs[filename]

df_attributes = infer_dtypes(df)
df_attributes
# Out:
# customer_id
# customer_unique_id
# customer_zip_code_prefix
# customer_city
# customer_state
#                          has_unique_entries has_nulls where_nulls total_nulls  \
# customer_id                               1         0          []           0
# customer_unique_id                        0         0          []           0
# customer_zip_code_prefix                  0         0          []           0
# customer_city                             0         0          []           0
# customer_state                            0         0          []           0
#
#                                         sorted_chars_used  \
# customer_id                              0123456789abcdef
# customer_unique_id                       0123456789abcdef
# customer_zip_code_prefix                       0123456789
# customer_city              '-14abcdefghijklmnopqrstuvwxyz
# customer_state                          ABCDEFGIJLMNOPRST
#
# ...

# %%
df.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix    object
# customer_city               object
# customer_state              object
# dtype: object
